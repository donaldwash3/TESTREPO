# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Donald Washington**
#
#     Data Scientist

# %% [markdown]
# *I am interested in Data Science because it provides me with the tools to solve many puzzles of the world. Data Science is problem solving profession that will allow humanity to unravel the mysteries of today, tomorrow, and history.*

# %% [markdown]
# ### The code in Cell 5 will solve a mathamatical problem

# %%
2*2
# Out:
# 4

# %% [markdown]
# This assignment was completed using [GitHub Pages](https://pages.github.com/)
#
# ![This is an image](https://myoctocat.com/assets/images/base-octocat.svg)
#
# - Blue
# - Yellow
# - Green
